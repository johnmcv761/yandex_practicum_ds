# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-расчета-эффективности" data-toc-modified-id="Проверка-расчета-эффективности-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Проверка расчета эффективности</a></span></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Пропуски</a></span></li><li><span><a href="#Приведение-типов" data-toc-modified-id="Приведение-типов-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Приведение типов</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Дубликаты</a></span></li></ul></li><li><span><a href="#Корреляция-признаков" data-toc-modified-id="Корреляция-признаков-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Корреляция признаков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Концентрация-металлов-(Au,-Ag,-Pb)-на-разных-этапах-очистки" data-toc-modified-id="Концентрация-металлов-(Au,-Ag,-Pb)-на-разных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Концентрация металлов (Au, Ag, Pb) на разных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Au" data-toc-modified-id="Au-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Au</a></span></li><li><span><a href="#Ag" data-toc-modified-id="Ag-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Ag</a></span></li><li><span><a href="#Pb" data-toc-modified-id="Pb-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Pb</a></span></li><li><span><a href="#Нулевые-концентрации" data-toc-modified-id="Нулевые-концентрации-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Нулевые концентрации</a></span></li></ul></li><li><span><a href="#Распределения-размеров-гранул-на-учебной-и-тестовой-выборках" data-toc-modified-id="Распределения-размеров-гранул-на-учебной-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределения размеров гранул на учебной и тестовой выборках</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-разных-стадиях" data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-разных-стадиях-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на разных стадиях</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Функции-для-расчета-sMape" data-toc-modified-id="Функции-для-расчета-sMape-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функции для расчета sMape</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Подготовка данных</a></span></li><li><span><a href="#Dummy-Regression-(mean)" data-toc-modified-id="Dummy-Regression-(mean)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Dummy Regression (mean)</a></span></li><li><span><a href="#Dummy-Regression-(median)" data-toc-modified-id="Dummy-Regression-(median)-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Dummy Regression (median)</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Линейная регрессия</a></span><ul class="toc-item"><li><span><a href="#Значимость-признаков" data-toc-modified-id="Значимость-признаков-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Значимость признаков</a></span></li><li><span><a href="#Мультиколлинеарность" data-toc-modified-id="Мультиколлинеарность-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Мультиколлинеарность</a></span></li></ul></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Случайный лес</a></span><ul class="toc-item"><li><span><a href="#Значимость-признаков" data-toc-modified-id="Значимость-признаков-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Значимость признаков</a></span></li><li><span><a href="#Подбор-гиперпараметров" data-toc-modified-id="Подбор-гиперпараметров-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>Подбор гиперпараметров</a></span></li></ul></li><li><span><a href="#Проверка-на-тестовой-выборке" data-toc-modified-id="Проверка-на-тестовой-выборке-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Проверка на тестовой выборке</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.auto import tqdm

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor

from sklearn.metrics import mean_absolute_error, make_scorer
from sklearn.model_selection import cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler

from scipy.stats import ttest_ind, levene, median_test

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Подготовка данных

# %%
train = pd.read_csv('/content/gold_recovery_train.csv')
test = pd.read_csv('/content/gold_recovery_test.csv')
full = pd.read_csv('/content/gold_recovery_full.csv')

# %%
full.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
test.head()
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
train.head()
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
df = [full, train, test]
df_names = ['full', 'train', 'test']

# %%
for i in range(3):
    display(df_names[i])
    df[i].info()
    display(df[i].head())
# Out:
# 'full'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22716 entries, 0 to 22715
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                22716 non-null  object
#  1   final.output.concentrate_ag                         22627 non-null  float64
#  2   final.output.concentrate_pb                         22629 non-null  float64
#  3   final.output.concentrate_sol                        22331 non-null  float64
#  4   final.output.concentrate_au                         22630 non-null  float64
#  5   final.output.recovery                               20753 non-null  float64
#  6   final.output.tail_ag                                22633 non-null  float64
#  7   final.output.tail_pb                                22516 non-null  float64
# ...

# %%
display(f'Доля тестовых данных {len(test)/len(full)}')
display(f'Доля данных в обучающей выборке {len(train)/len(full)}')
# Out:
# 'Доля тестовых данных 0.2577918647649234'
# 'Доля данных в обучающей выборке 0.7422081352350766'

# %% [markdown]
# * Видим, что датафреймы большие: всего 22715 строк и 87 колонок в датафрейме **full**.  Тестовая выборка составляет около 26% всех данных, обучающая - около 74%.
# * Видим, что при импорте тип данных определен правильно везде, кроме `date`, в котором должен быть тип дата-время.
#
# Проверим, что длины датафреймов соответствуют информации о том, что **full** разбит на **train** и **test**.

# %%
try:
    assert len(train) + len(test) == len(full)
    display('Сумма размеров train и test равна размеру full')
except:
    display('Сумма размеров train и test не равна размеру full')
# Out:
# 'Сумма размеров train и test равна размеру full'

# %% [markdown]
# ### Проверка расчета эффективности

# %% [markdown]
# Проверим правильность расчета recovery на обучающей выборке после этапа флотации (черновой концентрат).

# %%
def recovery_calculation(c, f, t):
    return 100 * c * (f - t) / (f * (c - t))

# %%
train['rougher.output.recovery_check'] = recovery_calculation(c=train['rougher.output.concentrate_au'],
                                                              f=train['rougher.input.feed_au'],
                                                              t=train['rougher.output.tail_au'])

display(train[['rougher.output.recovery_check', 'rougher.output.recovery']].sample(5, random_state=42))

display('MAE между rougher.output.recovery и посчитанными вручную значениями:')
try:
    display(mean_absolute_error(train['rougher.output.recovery'], train['rougher.output.recovery_check']))
except:
    display('Посчитать MAE не удалось')
    display("ValueError: Input contains NaN, infinity or a value too large for dtype('float64').")
# Out:
#        rougher.output.recovery_check  rougher.output.recovery
# 8460                       80.452391                80.452391
# 12793                      91.475488                91.475488
# 733                        88.043196                88.043196
# 6395                       89.855210                89.855210
# 10452                      80.723218                80.723218
# 'MAE между rougher.output.recovery и посчитанными вручную значениями:'
# 'Посчитать MAE не удалось'
# "ValueError: Input contains NaN, infinity or a value too large for dtype('float64')."

# %% [markdown]
# Визуально видим, что расчеты совпадают, но MAE не можем посчитать из-за наличия "нехороших" значений (NaN, inf) в данных.

# %%
try:
    assert len(train['rougher.output.recovery'].dropna()) == len(train['rougher.output.recovery_check'].dropna())
    display('Количество NaN-ов совпадает')
except:
    display('Разница в количестве NaN в исходном датафрейме и рассчитанных вручную значениях')
    display(train['rougher.output.recovery'].isna().sum() -
            train['rougher.output.recovery_check'].isna().sum())
# Out:
# 'Разница в количестве NaN в исходном датафрейме и рассчитанных вручную значениях'
# 290

# %% [markdown]
# Видим, что количество NaN не совпадает: в предоставленном датафрейме их на 343 больше, чем мы получили при ручном расчете. Посмотрим на несовпадающие NaN-ы.

# %%
cond1 = (train['rougher.output.recovery'].isna() & train['rougher.output.recovery_check'].notna())
cond2 = (train['rougher.output.recovery'].notna() & train['rougher.output.recovery_check'].isna())

train[cond1 | cond2][['rougher.output.recovery_check', 'rougher.output.recovery']]
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:49: RuntimeWarning: invalid value encountered in reduce
#   return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#        rougher.output.recovery_check  rougher.output.recovery
# 53                        188.742102                      NaN
# 372                     -3913.312866                      NaN
# 377                      -116.312118                      NaN
# 560                        -1.086185                      NaN
# 700                   -112789.873301                      NaN
# ...                              ...                      ...
# 16697                     112.957805                      NaN
# 16698                     100.442153                      NaN
# 16699                      -0.482567                      NaN
# 16700                      -0.584325                      NaN
# 16701                      -1.498298                      NaN
#
# [290 rows x 2 columns]

# %%
display('rougher.output.recovery_check')
display(train[cond1 | cond2]['rougher.output.recovery_check'].value_counts(dropna=False))
display('rougher.output.recovery')
display(train[cond1 | cond2]['rougher.output.recovery'].value_counts(dropna=False))
# Out:
# 'rougher.output.recovery_check'
# rougher.output.recovery_check
# -inf           29
#  188.742102     1
# -0.629835       1
# -0.581678       1
# -0.623746       1
#                ..
#  127.129732     1
#  102.768334     1
# -62.421549      1
# -133.632981     1
# -1.498298       1
# Name: count, Length: 262, dtype: int64
# 'rougher.output.recovery'
# rougher.output.recovery
# NaN    290
# Name: count, dtype: int64

# %% [markdown]
# Интересно. Во-первых, видим, что нет ситуаций, когда в датафрейме есть значение, а в посчитанных руками данных - NaN. Во-вторых, видим, что среди значений, рассчитанных руками много странных значений: отрицательные значения эффективности, значения, превышащие 100, бесконечности. Посмотрим есть ли среди этих значений значения из ожидаемого интервала значений [0; 100].

# %%
cond3 = (0 <= train['rougher.output.recovery_check']) & (train['rougher.output.recovery_check'] <= 100)
train[(cond1 | cond2) & cond3]['rougher.output.recovery_check']
# Out:
# Series([], Name: rougher.output.recovery_check, dtype: float64)

# %% [markdown]
# Видим, что таких нет. Значит, в `rougher.output.recovery` они как раз отсеяны и помечены как NaN.
#
# Посчитаем MAE, дропнув NaNы в двух рассматриваемых столбцах.

# %%
cleaned = train[['rougher.output.recovery_check', 'rougher.output.recovery']].dropna()

display('MAE между rougher.output.recovery и посчитанными вручную значениями:')
mean_absolute_error(cleaned['rougher.output.recovery'], cleaned['rougher.output.recovery_check'])
# Out:
# 'MAE между rougher.output.recovery и посчитанными вручную значениями:'
# 1.1101950495226952e-14

# %%
cleaned['delta'] = abs(cleaned['rougher.output.recovery'] - cleaned['rougher.output.recovery_check'])
cleaned[cleaned['delta'] !=0].sort_values(by='delta', ascending=False).head()
# Out:
#        rougher.output.recovery_check  rougher.output.recovery         delta
# 2775                       74.893994                74.893994  5.684342e-14
# 7836                       97.756449                97.756449  5.684342e-14
# 5037                       34.915704                34.915704  5.684342e-14
# 14961                      93.532080                93.532080  5.684342e-14
# 13124                      90.740540                90.740540  5.684342e-14

# %% [markdown]
# Видим, что эффективность посчитана корректно, отклонения пренебрежимо малы.

# %%
train = train.drop(columns=['rougher.output.recovery_check'])

# %% [markdown]
# Объекты с пропусками в целевых `rougher.output.recovery` обработаем на стадии предобработки, пока сохраним их.

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке

# %%
display('Разница в количестве столбцов train-test: ' +
        str(len(train.columns) - len(test.columns)))
# Out:
# 'Разница в количестве столбцов train-test: 34'

# %%
set(train.columns) - set(test.columns)
# Out:
# {'final.output.concentrate_ag',
#  'final.output.concentrate_au',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_au',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_au',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_au',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.recovery',
# ...

# %% [markdown]
# Сопоставим полный список признаков из **train** с множеством отсутствующих признаков в **test**, полученным выше. Цветом выделены отсутствующие признаки: желтым цветом - промежуточные, зеленым - целевые.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Видим, что в **test** отсутствуют следующие признаки:
# * целевые для нас признаки `rougher.output.recovery` и `final.output.recovery`;
# * этап флотации (rougher): все характеристики продукта (output) и расчетные характеристики (calculation);
# * этап первичной очистки (primary_cleaner): все характеристики продукта (output);
# * этап вторично очистки (secondary_cleaner): все характеристики продукта (output);
# * финальные характеристики (final): все характеристики продукта (output).
#
# Итого в **test** отсутствуют все характеристики, связанные с характеристиками продуктов (output) всех этапов, включая эффективности обогащения, которые по ним рассчитываются, а также расчетные характеристики (calculation). При этом сохранена вся информация о входных параметрах (input) сырья на первом этапе (rougher) и добавок на втором этапе (primary_cleaner), а также информация о параметрах, характеризующих текущие состояния этапов (state) для всех этапов.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# Так как нам доступен датафрейм **full** с полным набором данных, на стадии подготовки данных работать будем с ним в первую очередь. После внесения изменений в **full**, будем обновлять **train** и **test**.

# %% [markdown]
# #### Пропуски

# %%
for i in range(3):
    df[i].isna().mean().hist()
    plt.title('Доля пропусков в датафрейме ' + df_names[i])
    plt.xlabel('Доля пропусков')
    plt.ylabel('Количество признаков')
    plt.show()
    display(df[i].isna().mean().sort_values(ascending=False).head())
# Out:
# rougher.output.recovery               0.137304
# rougher.output.tail_ag                0.120488
# rougher.output.tail_au                0.120444
# rougher.output.tail_sol               0.120444
# rougher.input.floatbank11_xanthate    0.099357
# dtype: float64
# rougher.output.recovery          0.152610
# rougher.output.recovery_check    0.135409
# rougher.output.tail_ag           0.133452
# rougher.output.tail_au           0.133393
# rougher.output.tail_sol          0.133393
# dtype: float64
# rougher.input.floatbank11_xanthate    0.060280
# primary_cleaner.input.sulfate         0.051571
# primary_cleaner.input.depressant      0.048497
# rougher.input.floatbank10_sulfate     0.043887
# primary_cleaner.input.xanthate        0.028347
# dtype: float64

# %% [markdown]
# Видим, что доля пропусков в признаках достигает 15%. Наибольшее количество пропусков в датафреймах **full** и **train** в признаке `rougher.output.recovery`, который отсутствует в **test**, т.к. это один из двух наших целевых признаков. Посмотрим, какую часть данных мы потеряем, если удалим все пропущенные значения.

# %%
part = 1 - len(full.dropna()) / len(full)
display(f'Доля данных к удалению: {part}')
# Out:
# 'Доля данных к удалению: 0.2915125902447614'

# %% [markdown]
# Видим, что потеряем около 30% данных. Это много. В **test** присутствуют не все признаки, доступные нам в **train** и **full**, поэтому для обучения модели мы будем использовать те, которые есть в **test**. Посмотрим, какую часть данных мы потеряем, если удалим пропуски только в данных, которые будут использоваться для обучения.

# %%
columns_to_check = list(set(train.columns) - (set(train.columns) - set(test.columns)))
part = 1 - len(full[columns_to_check].dropna()) / len(full)
display(f'Доля данных к удалению: {part}')
# Out:
# 'Доля данных к удалению: 0.16776721253741855'

# %% [markdown]
# Видим, что потеряем около 17% данных, это заметно лучше 30%. Сохраним в df_raw копию полных данных и удалим пропуски.
#
# После этого нам нужно будет удалить из **train** и **test** данные, которые мы удалили из **full**. К сожалению, индексы у датафреймов не согласованы, поэтому связать датафреймы через них мы не сможем, но у нас есть уникальная дата для каждого наблюдения. Воспользуемся ей, чтобы согласовать изменения в датафреймах, предварительно проверив, что даты действительно уникальны.

# %%
full['date'].value_counts(ascending=False).head()
# Out:
# date
# 2016-01-15 00:00:00    1
# 2017-10-08 04:59:59    1
# 2017-10-07 04:59:59    1
# 2017-10-07 03:59:59    1
# 2017-10-07 02:59:59    1
# Name: count, dtype: int64

# %%
df_raw  = df.copy()
# df_raw[0] - full, df_raw[1] - train, df_raw[2] - test
display('Размер full до очистки ' + str(len(full)))
full = full.dropna(subset=columns_to_check)
display('Размер full после очистки ' + str(len(full)))
# Out:
# 'Размер full до очистки 22716'
# 'Размер full после очистки 18905'

# %% [markdown]
# Еще нужно удалить пропуски из целевых признаков.

# %%
target_columns = ['rougher.output.recovery', 'final.output.recovery']
display('Размер full до очистки ' + str(len(full)))
full = full.dropna(subset=target_columns)
display('Размер full после очистки ' + str(len(full)))
# Out:
# 'Размер full до очистки 18905'
# 'Размер full после очистки 17908'

# %%
def update_train_test(full=full, train=train, test=test):
    full_dates = full['date']

    display('Размер train до обновления ' + str(len(train)))
    display('Размер train после обновления ' + str(len(train.query('date in @full_dates'))))

    display('Размер test до обновления ' + str(len(test)))
    display('Размер test после обновления ' + str(len(test.query('date in @full_dates'))))

    return train.query('date in @full_dates'), test.query('date in @full_dates')

# %%
def check_train_test():
    display(f'Доля тестовых данных {len(test)/len(full)}')
    display(f'Доля данных в обучающей выборке {len(train)/len(full)}')
    display(f'Размер full - {len(full)}')
    try:
        assert len(train) + len(test) == len(full)
        display('Сумма размеров train и test равна размеру full')
    except:
        display('Сумма размеров train и test не равна размеру full')

# %%
train, test = update_train_test(full, train, test)

check_train_test()
# Out:
# 'Размер train до обновления 16860'
# 'Размер train после обновления 12679'
# 'Размер test до обновления 5856'
# 'Размер test после обновления 5229'
# 'Доля тестовых данных 0.29199240562876927'
# 'Доля данных в обучающей выборке 0.7080075943712307'
# 'Размер full - 17908'
# 'Сумма размеров train и test равна размеру full'

# %% [markdown]
# #### Приведение типов

# %% [markdown]
# При импорте тип данных был определен правильно везде, кроме `date`, в котором должен быть тип дата-время. При этом мы ожидаем, что целевые признаки зависят от характеристик сырья и параметров обработки, но не от даты-времени обработки. При этом `date` нам может пригодиться для согласования изменений в датафреймах, поэтому сохраним его, приведя к datetime. Удалим его, когда будем готовить данные для обучения моделей.

# %%
full['date'].head()
# Out:
# 0    2016-01-15 00:00:00
# 1    2016-01-15 01:00:00
# 2    2016-01-15 02:00:00
# 3    2016-01-15 03:00:00
# 4    2016-01-15 04:00:00
# Name: date, dtype: object

# %%
pd.to_datetime(full['date'], format='%Y-%m-%d %H:%M:%S')
# Out:
# 0       2016-01-15 00:00:00
# 1       2016-01-15 01:00:00
# 2       2016-01-15 02:00:00
# 3       2016-01-15 03:00:00
# 4       2016-01-15 04:00:00
#                 ...
# 22711   2018-08-18 06:59:59
# 22712   2018-08-18 07:59:59
# 22713   2018-08-18 08:59:59
# 22714   2018-08-18 09:59:59
# 22715   2018-08-18 10:59:59
# Name: date, Length: 17908, dtype: datetime64[ns]

# %%
full['date'] = pd.to_datetime(full['date'], format='%Y-%m-%d %H:%M:%S')
train['date'] = pd.to_datetime(train['date'], format='%Y-%m-%d %H:%M:%S')
test['date'] = pd.to_datetime(test['date'], format='%Y-%m-%d %H:%M:%S')
for df in [full, train, test]:
    df[['date']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17908 entries, 0 to 22715
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    17908 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 279.8 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 12679 entries, 0 to 16859
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    12679 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 198.1 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 5229 entries, 0 to 5855
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    5229 non-null   datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 81.7 KB
# <ipython-input-34-f236a43f6351>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# #### Дубликаты

# %%
full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет, двигаемся дальше.

# %% [markdown]
# ### Корреляция признаков

# %%
check_corr_columns = list(test.columns) + target_columns

sns.heatmap(full[check_corr_columns].corr())
plt.show()
display(full[check_corr_columns].corr())
# Out:
#                                                 date  \
# date                                        1.000000
# primary_cleaner.input.sulfate               0.191828
# primary_cleaner.input.depressant           -0.119190
# primary_cleaner.input.feed_size            -0.349381
# primary_cleaner.input.xanthate              0.201604
# primary_cleaner.state.floatbank8_a_air      0.130327
# primary_cleaner.state.floatbank8_a_level   -0.091259
# primary_cleaner.state.floatbank8_b_air      0.113676
# primary_cleaner.state.floatbank8_b_level   -0.115518
# primary_cleaner.state.floatbank8_c_air      0.133737
# primary_cleaner.state.floatbank8_c_level   -0.106740
# primary_cleaner.state.floatbank8_d_air      0.237752
# primary_cleaner.state.floatbank8_d_level   -0.111300
# rougher.input.feed_ag                      -0.025204
# rougher.input.feed_pb                       0.291465
# rougher.input.feed_rate                     0.307625
# rougher.input.feed_size                     0.316659
# ...

# %% [markdown]
# Видим большое количество сильных корреляций между признаками. Нужно будет попробовать уменьшить количество признаков при построении модели.

# %% [markdown]
# ### Вывод

# %% [markdown]
# * На входе мы имели 22715 строк и 87 колонок в датафрейме **full**.  Тестовая выборка составляла около 26% всех данных, обучающая - около 74%.
# * После очистки от пропусков размер **full** сократился до 17908 строк. Доля тестовых данных - 29%, доля обучающей выборки - 71%.
# * Видим, что при импорте тип данных определен правильно везде, кроме `date`, в котором должен быть тип дата-время. Привели его к типу datetime.
# * Дубликаты не обнаружены.
# * Данные об эффективности обогащения, предоставленные нам, согласуются со значениями, полученными вручную по формуле.
# * В тестовой выборке недоступны все характеристики, связанные с характеристиками продуктов (output) всех этапов, включая эффективности обогащения, которые по ним рассчитываются, а также расчетные характеристики (calculation).
# * Видим большое количество сильных корреляций между признаками. Нужно будет попробовать уменьшить количество признаков при построении модели.
#
# Что еще можно попробовать: вместо удаления пропусков можно было попробовать заполнить их соседними значениями. Как мы знаем <u><i>соседние по времени параметры часто похожи</i></u>.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Анализ данных

# %%
df = [full, train, test] #обновим данные в списке

# %% [markdown]
# ### Концентрация металлов (Au, Ag, Pb) на разных этапах очистки

# %% [markdown]
# Будем смотреть концентрации в **full**, т.к. он нам доступен и там собраны все доступные нам данные. Перед построением моделей обновим **train** и **test** по индексам **full**.

# %%
metals = ['au', 'ag', 'pb']
concentrate_column_names = [[] for _ in range(3)]

for i, metal_name in enumerate(metals):
    for prefix in ['rougher.input.feed_', 'rougher.output.concentrate_', 'primary_cleaner.output.concentrate_',
                   'final.output.concentrate_']:
        concentrate_column_names[i].append(prefix+metal_name)

for i, metal_name in enumerate(metals):
    display(metal_name + ': '+ ', '.join(concentrate_column_names[i]))
# Out:
# 'au: rougher.input.feed_au, rougher.output.concentrate_au, primary_cleaner.output.concentrate_au, final.output.concentrate_au'
# 'ag: rougher.input.feed_ag, rougher.output.concentrate_ag, primary_cleaner.output.concentrate_ag, final.output.concentrate_ag'
# 'pb: rougher.input.feed_pb, rougher.output.concentrate_pb, primary_cleaner.output.concentrate_pb, final.output.concentrate_pb'

# %%
def boxplot_concentrates():
    concentrates = [[] for _ in range(3)]
    for i, metal_name in enumerate(metals):
        concentrates[i] = full[concentrate_column_names[i]]
        concentrates[i].columns = [f'rougher_feed_{metal_name}', f'rougher_{metal_name}',
                                   f'primary_{metal_name}', f'final_{metal_name}']

        concentrates[i].index = full.index
        concentrates[i].boxplot()
        plt.title(f'Концентрация {metal_name.upper()} на разных этапах')
        plt.show()
        display(concentrates[i].describe()[1:2])
    return concentrates

# %%
concentrates = boxplot_concentrates()
# Out:
#       rougher_feed_au  rougher_au  primary_au   final_au
# mean         8.314462   19.918702   32.152759  44.192262
#       rougher_feed_ag  rougher_ag  primary_ag  final_ag
# mean         8.815913   12.020012    8.501495  5.152988
#       rougher_feed_pb  rougher_pb  primary_pb   final_pb
# mean         3.606202     7.65045    9.878357  10.018815

# %% [markdown]
# * Видим, что концентрация золота постепенно растет от этапа к этапу.
# * Концентрация серебра растет на этапе флотации, а потом постепенно падает.
# * Концентрация свинца растет во время флотации и первичной очистки, но практически не меняется после вторичной.
#
# Это верно для средних значений. При этом для золота мы видим, что присутствуют финальные концентрации близкие к нулю, что странно. Для начала посмотрим, есть ли ситуации, когда концентрация золота падает, а не растет.

# %% [markdown]
# #### Au

# %%
concentrates[0].head()
# Out:
#    rougher_feed_au  rougher_au  primary_au   final_au
# 0         6.486150   19.793808   34.174427  42.192020
# 1         6.478583   20.050975   34.118526  42.701629
# 2         6.362222   19.737170   33.969464  42.657501
# 3         6.118189   19.320810   28.260743  42.689819
# 4         5.663707   19.216101   33.044932  42.774141

# %%
cond1 = 'rougher_feed_au > rougher_au'
cond2 = 'rougher_au > primary_au'
cond3 = 'primary_au > final_au'
display('Концентрация AU после флотации меньше, чем до флотации:',
        len(concentrates[0].query(cond1)) / len(concentrates[0]))
display('Концентрация AU после первичной очистки меньше, чем после флотации:',
        len(concentrates[0].query(cond2)) / len(concentrates[0]))
display('Концентрация AU после вторичной очистки меньше, чем после первичной:',
        len(concentrates[0].query(cond3)) / len(concentrates[0]))
# Out:
# 'Концентрация AU после флотации меньше, чем до флотации:'
# 0.0171990171990172
# 'Концентрация AU после первичной очистки меньше, чем после флотации:'
# 0.02389993299084208
# 'Концентрация AU после вторичной очистки меньше, чем после первичной:'
# 0.014686173777082869

# %% [markdown]
# Видим, что доля ситуаций, когда концентрация золота падает при продвижении по этапам очистки - не более 8% от всех. Удалим их из датафрейма.

# %%
display('Размер до удаления ' + str(len(full)))
full = full.drop(concentrates[0].query(cond1 + '|' + cond2 + '|' + cond3).index, errors='ignore')
display('Размер после удаления ' + str(len(full)))
# Out:
# 'Размер до удаления 17908'
# 'Размер после удаления 16923'

# %% [markdown]
# #### Ag

# %% [markdown]
# Мы видeли, что средняя концентрация растет во время флотации, а потом падает по мере прохождения этапов очистки. Посмотрим, есть ли ситуации, когда она ведет себя не так

# %%
concentrates[1].head()
# Out:
#    rougher_feed_ag  rougher_ag  primary_ag  final_ag
# 0         6.100378   11.500771    8.547551  6.055403
# 1         6.161113   11.615865    8.558743  6.029369
# 2         6.116455   11.695753    8.603505  6.055926
# 3         6.043309   11.915047    7.221879  6.047977
# 4         6.060915   12.411054    9.089428  6.148599

# %%
cond4 = 'rougher_feed_ag > rougher_ag'
cond5 = 'rougher_ag < primary_ag'
cond6 = 'primary_ag < final_ag'
display('Концентрация Ag после флотации меньше, чем до флотации:',
        len(concentrates[1].query(cond4)) / len(concentrates[1]))
display('Концентрация Ag после первичной очистки больше, чем после флотации:',
        len(concentrates[1].query(cond5)) / len(concentrates[1]))
display('Концентрация Ag после вторичной очистки больше, чем после первичной:',
        len(concentrates[1].query(cond6)) / len(concentrates[1]))
# Out:
# 'Концентрация Ag после флотации меньше, чем до флотации:'
# 0.036966718784900605
# 'Концентрация Ag после первичной очистки больше, чем после флотации:'
# 0.037971856153674335
# 'Концентрация Ag после вторичной очистки больше, чем после первичной:'
# 0.03182935001116819

# %% [markdown]
# Удаление строк со необычным поведением концентрации серебра в процессе будет стоить нам еще не более 14% выборки.

# %%
display('Размер до удаления ' + str(len(full)))
full = full.drop(concentrates[1].query(cond4 + '|' + cond5 + '|' + cond6).index, errors='ignore')
display('Размер после удаления ' + str(len(full)))
# Out:
# 'Размер до удаления 16923'
# 'Размер после удаления 16214'

# %% [markdown]
# #### Pb

# %% [markdown]
# Посмотрим аналогичным образом на концентрации свинца. В этом случае видим заметный рост концентрации только на флотации и первичной очистке, поэтому проверять будем именно эти условия.

# %%
concentrates[2].head()
# Out:
#    rougher_feed_pb  rougher_pb  primary_pb   final_pb
# 0         2.284912    7.101074   10.389648   9.889648
# 1         2.266033    7.278807   10.497069   9.968944
# 2         2.159622    7.216833   10.354494  10.213995
# 3         2.037807    7.175616    8.496563   9.977019
# 4         1.786875    7.240205    9.986786  10.142511

# %%
cond7 = 'rougher_feed_pb > rougher_pb'
cond8 = 'rougher_pb > primary_pb'
display('Концентрация Pb после флотации меньше, чем до флотации:',
        len(concentrates[2].query(cond7)) / len(concentrates[2]))
display('Концентрация Pb после первичной очистки меньше, чем после флотации:',
        len(concentrates[2].query(cond8)) / len(concentrates[2]))
# Out:
# 'Концентрация Pb после флотации меньше, чем до флотации:'
# 0.018706723252177797
# 'Концентрация Pb после первичной очистки меньше, чем после флотации:'
# 0.12776412776412777

# %%
display('Размер до удаления ' + str(len(full)))
full = full.drop(concentrates[2].query(cond7 + '|' + cond8).index, errors='ignore')
display('Размер после удаления ' + str(len(full)))
# Out:
# 'Размер до удаления 16214'
# 'Размер после удаления 14572'

# %%
concentrates = boxplot_concentrates()
# Out:
#       rougher_feed_au  rougher_au  primary_au   final_au
# mean          8.44291   20.380468   32.636398  44.819828
#       rougher_feed_ag  rougher_ag  primary_ag  final_ag
# mean         8.917476   12.463234    8.782679  5.136988
#       rougher_feed_pb  rougher_pb  primary_pb   final_pb
# mean         3.678261    7.872643    10.55595  10.111561

# %% [markdown]
# #### Нулевые концентрации

# %% [markdown]
# Посмотрим на записи с нулевыми значениями концентраций.

# %%
zero_indexes = set()
for df_con in concentrates:
    for column in df_con.columns:
        zero_indexes = zero_indexes.union(df_con[df_con[column] == 0].index)

display(f'Обнаружено нулевых значений {len(zero_indexes)}')
# Out:
# 'Обнаружено нулевых значений 0'

# %%
concentrate_column_names[0] + concentrate_column_names[1] + concentrate_column_names[2]
# Out:
# ['rougher.input.feed_au',
#  'rougher.output.concentrate_au',
#  'primary_cleaner.output.concentrate_au',
#  'final.output.concentrate_au',
#  'rougher.input.feed_ag',
#  'rougher.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_ag',
#  'final.output.concentrate_ag',
#  'rougher.input.feed_pb',
#  'rougher.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_pb',
#  'final.output.concentrate_pb']

# %%
all_concentrate_column_names = concentrate_column_names[0] + concentrate_column_names[1] + concentrate_column_names[2]
full[all_concentrate_column_names].query('index in @zero_indexes')
# Out:
# Empty DataFrame
# Columns: [rougher.input.feed_au, rougher.output.concentrate_au, primary_cleaner.output.concentrate_au, final.output.concentrate_au, rougher.input.feed_ag, rougher.output.concentrate_ag, primary_cleaner.output.concentrate_ag, final.output.concentrate_ag, rougher.input.feed_pb, rougher.output.concentrate_pb, primary_cleaner.output.concentrate_pb, final.output.concentrate_pb]
# Index: []

# %% [markdown]
# Удалим обнаруженные объекты.

# %%
display(f'Размер до удаления {len(full)}')
full = full.drop(zero_indexes)
display(f'Размер после удаления {len(full)}')
# Out:
# 'Размер до удаления 14572'
# 'Размер после удаления 14572'

# %% [markdown]
# ### Распределения размеров гранул на учебной и тестовой выборках

# %% [markdown]
# Обновим **train** и **test** после сделанных изменений

# %%
train, test = update_train_test(full, train, test)

check_train_test()
# Out:
# 'Размер train до обновления 12679'
# 'Размер train после обновления 9850'
# 'Размер test до обновления 5229'
# 'Размер test после обновления 4722'
# 'Доля тестовых данных 0.32404611583859455'
# 'Доля данных в обучающей выборке 0.6759538841614054'
# 'Размер full - 14572'
# 'Сумма размеров train и test равна размеру full'

# %%
feedsize_column_names = []
for column in df[2].columns:
        if 'feed_size' in column:
            feedsize_column_names.append(column)
feedsize_column_names.sort(reverse=True)
feedsize_column_names
# Out:
# ['rougher.input.feed_size', 'primary_cleaner.input.feed_size']

# %%
df_feedsize = pd.DataFrame()
alpha = 0.05

for column in feedsize_column_names:

    train[column].plot(kind='hist', bins=30, grid=True, legend=True, label='train')
    test[column].plot(kind='hist', bins=30, grid=True, legend=True, label='test')
    plt.title(column)
    plt.show()

    mean_train, std_train, _, _,  median_train = train[column].describe()[1:6]
    mean_test, std_test, _, _, median_test_ = test[column].describe()[1:6]

    display(pd.DataFrame({'train': [mean_train, std_train, std_train**2, median_train],
                      'test': [mean_test, std_test, std_test**2, median_test_]},
                    index=['mean', 'std', 'disp', 'median']))

    display('Levene test for dispersions')
    display(f'Нулевая гипотеза: дисперсии {column} равны')
    levene_pvalue = levene(train[column], test[column]).pvalue
    display(f'Pvalue = {levene_pvalue}')
    if levene_pvalue < alpha:
        display('Отвергаем нулевую гипотезу: дисперсии не равны')
        disp_are_equal = False
    else:
        display('Не получилось отвергнуть нулевую гипотезу: дисперсии равны')
        disp_are_equal = True
    display('-------------')


    display('Mood median test ')
    display(f'Нулевая гипотеза: медианы {column} равны')
    median_test_pvalue = median_test(train[column], test[column])[1]
    display(f'Pvalue = {median_test_pvalue}')
    if median_test_pvalue < alpha:
        display('Отвергаем нулевую гипотезу: медианы не равны')
    else:
        display('Не получилось отвергнуть нулевую гипотезу: медианы равны')
    display('-------------')

    display('T-test')
    display('Нулевая гипотеза: средние двух выборок равны.')
    pvalue = ttest_ind(train[column], test[column], equal_var=disp_are_equal).pvalue
    display('pvalue: ' +  str(pvalue))
    if pvalue < alpha:
        display('Отвергаем нулевую гипотезу: средние не равны')
    else:
        display('Не получилось отвергнуть нулевую гипотезу: средние равны')
# Out:
#              train        test
# mean     58.997616   55.248400
# std      20.581867   14.942068
# disp    423.613258  223.265404
# median   54.848316   50.765527
# 'Levene test for dispersions'
# 'Нулевая гипотеза: дисперсии rougher.input.feed_size равны'
# 'Pvalue = 0.25888092874820534'
# 'Не получилось отвергнуть нулевую гипотезу: дисперсии равны'
# '-------------'
# 'Mood median test '
# 'Нулевая гипотеза: медианы rougher.input.feed_size равны'
# 'Pvalue = 4.237155938222522e-26'
# 'Отвергаем нулевую гипотезу: медианы не равны'
# '-------------'
# 'T-test'
# 'Нулевая гипотеза: средние двух выборок равны.'
# 'pvalue: 6.402650798623968e-29'
# 'Отвергаем нулевую гипотезу: средние не равны'
#            train      test
# mean    7.334188  7.280865
# std     0.601122  0.579160
# disp    0.361348  0.335427
# median  7.290000  7.250000
# 'Levene test for dispersions'
# 'Нулевая гипотеза: дисперсии primary_cleaner.input.feed_size равны'
# 'Pvalue = 0.44075561297780896'
# ...

# %% [markdown]
# ### Суммарная концентрация всех веществ на разных стадиях

# %%
metals = ['au', 'ag', 'pb']
for step in ['rougher.input.feed_', 'rougher.output.concentrate_', 'primary_cleaner.output.concentrate_',
             'final.output.concentrate_']:
    full[step+'sum'] = full[[step+metal for metal in metals]].sum(axis=1)
    full[step+'sum'].plot(kind='hist', alpha=0.5, bins=30, legend=True, grid=True, figsize=(12, 8))
plt.title('Распределение суммарной концентрации металлов на разных этапах технологического процесса')
plt.xlabel('Суммарная концентрация металлов')
plt.show()

# %% [markdown]
# Распределения не идеальные, но явных аномалий не видим.

# %% [markdown]
# ### Вывод

# %% [markdown]
# I. Изучили концентрацию металлов на различных этапах очистки. Увидели, что:
# 1. средняя концентрация золота постепенно растет;
# 2. средняя концентрация серебра растет на этапе флотации, а потом постепенно падает;
# 3. концентрация свинца растет во время флотации и первичной очистки, но практически не меняется после вторичной.
#
# II. Удалили данные, выбивающиеся из описанных выше тенденций. Также удалили строки с нулевыми значениями концентраций. Размер **full** сократился до 14572 записей, доля тестовых данных - 32%, доля обучающей выборки - 68%.
#
# III. Сравнили распределения размеров гранул на обучающей и тестовой выборках. Увидели, что распределения в целом похожи и их характеристики отличаются не сильно, хоть и не проходят стат.тесты на равенство параметров распределений.
#
# IV. Исследовали суммарную концентрацию всех веществ на разных стадиях. Аномалии не обнаружены.

# %% [markdown]
# ## Модель

# %% [markdown]
# Для решения поставленной задачи попробуем три модели: линейную регрессию, как наиболее легко интерпретируемую,  и случайный лес, который показывал лучшие результаты ранее. Для оценки адекватности результатов будем сравнивать их с предсказаниями по среднему и по медиане.

# %% [markdown]
# ### Функции для расчета sMape

# %%
def sMape(y_true, y_pred):
    assert len(y_true) == len(y_pred)

    n = len(y_true)
    df = pd.DataFrame({'y_true': y_true, 'y_pred': y_pred})

    df['to_sum'] = 2 * abs(df['y_true'] - df['y_pred']) / (abs(df['y_true']) + abs(df['y_pred']))
    result = 100 * df['to_sum'].sum() / n

    return result

# %%
def final_Mape(y_true, y_pred):
    assert len(y_true) == len(y_pred)

    y_pred = pd.DataFrame(y_pred, columns=['rougher_pred', 'final_pred'])
    y_pred.index = y_true.index

    rougher_true = y_true['rougher.recovery_true']
    final_true = y_true['final.recovery_true']
    rougher_pred = y_pred['rougher_pred']
    final_pred = y_pred['final_pred']

    result = 0.25 * sMape(rougher_true, rougher_pred) + 0.75 * sMape(final_true, final_pred)

    return result

# %%
final_sMape_scorer = make_scorer(final_Mape)

# %% [markdown]
# ### Подготовка данных

# %% [markdown]
# При выделении features и target обратим внимание на два момента:
# 1. В **test** у нас нет целевых признаков, поэтому возьмем их из **full**, сопоставив объекты по `date`. В features пойдут все признаки, кроме `date`.
# 2. В features_train возьмем только те признаки, которые есть в features_test.

# %%
target_columns = ['rougher.output.recovery', 'final.output.recovery']

test_dates = test['date']
features_test_no_scaling = test.drop(columns=['date'])
target_test = full.query('date in @test_dates')[target_columns]

features_train_no_scaling = train[features_test_no_scaling.columns]
target_train = train[target_columns]
target_train.columns = ['rougher.recovery_true', 'final.recovery_true']

scaler = StandardScaler()
scaler.fit(features_train_no_scaling)
features_train = scaler.transform(features_train_no_scaling)
features_train = pd.DataFrame(features_train, columns=features_train_no_scaling.columns)
features_test = scaler.transform(features_test_no_scaling)
features_test = pd.DataFrame(features_test, columns=features_train_no_scaling.columns)

# %%
features_test
# Out:
#       primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                          2.007891                          1.840128
# 1                          2.139475                          1.838403
# 2                          2.135678                          1.195755
# 3                          2.137864                          0.927351
# 4                          1.672548                          0.522582
# ...                             ...                               ...
# 4717                       0.952044                          2.136698
# 4718                       0.922025                          2.148682
# 4719                       0.871170                          2.145951
# 4720                       1.116523                          1.976408
# 4721                       1.169818                          1.840964
#
#       primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# ...

# %%
target_test = target_test.reset_index().drop(columns=['index'])
target_test.columns = ['rougher.recovery_true', 'final.recovery_true']
target_test.head()
# Out:
#    rougher.recovery_true  final.recovery_true
# 0              89.993421            70.273583
# 1              88.089657            68.910432
# 2              88.412756            68.143213
# 3              87.360133            67.776393
# 4              83.236367            61.467078

# %%
# датафрейм для сопоставления результатов
cv_result_agg = pd.DataFrame(columns=['cv', 'test'])
cv_result_agg
# Out:
# Empty DataFrame
# Columns: [cv, test]
# Index: []

# %% [markdown]
# ### Dummy Regression (mean)

# %%
model_dummy_mean_cv = DummyRegressor(strategy='mean')
cv_results_dummy_mean = cross_val_score(model_dummy_mean_cv, features_train, target_train,
                scoring=final_sMape_scorer,
                cv=5)
display(f'Средний итоговый sMape = {cv_results_dummy_mean.mean()}')
# Out:
# 'Средний итоговый sMape = 8.204924967086132'

# %%
cv_result_agg.loc['dummy_mean', 'cv'] = cv_results_dummy_mean.mean()

# %% [markdown]
# ### Dummy Regression (median)

# %%
model_dummy_median_cv = DummyRegressor(strategy='median')
cv_results_dummy_median= cross_val_score(model_dummy_median_cv, features_train, target_train,
                scoring=final_sMape_scorer,
                cv=5)
display(f'Средний итоговый sMape = {cv_results_dummy_median.mean()}')
# Out:
# 'Средний итоговый sMape = 8.298086797492513'

# %%
cv_result_agg.loc['dummy_median', 'cv'] = cv_results_dummy_median.mean()

# %% [markdown]
# ### Линейная регрессия

# %%
model_lin_regr_cv = LinearRegression()
cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train, target_train,
                scoring=final_sMape_scorer,
                cv=5)
display(f'Средний итоговый sMape = {cv_results_model_lin_regr.mean()}')
# Out:
# 'Средний итоговый sMape = 8.123784039537925'

# %%
cv_result_agg.loc['lin_regr_base', 'cv'] = cv_results_model_lin_regr.mean()

# %% [markdown]
# У линейной регрессии результат даже чуть лучше, чем у Dummy Regressor. У нас много признаков (53), посмотрим на их значимость и посмотрим, как скажется на метрике отказ от наименее значимых признаков.

# %% [markdown]
# #### Значимость признаков

# %% [markdown]
# Посмотрим на признаки, вклад которых оказался наибольшим:

# %%
model_lin_regr = LinearRegression()
model_lin_regr.fit(features_train, target_train)

coef_table = pd.DataFrame(model_lin_regr.coef_, index=['rougher_coef', 'final_coef'],
             columns=features_train_no_scaling.columns).transpose()
coef_table['rougher_coef_abs'] = abs(coef_table['rougher_coef'])
coef_table['final_coef_abs'] = abs(coef_table['final_coef'])
display('Признаки, отсортированные по важности для rougher_recovery')
display(coef_table.sort_values(by='rougher_coef_abs', ascending=False).head(15))
display('Признаки, отсортированные по важности для final_recovery')
display(coef_table.sort_values(by='final_coef_abs', ascending=False).head(10))
# Out:
# 'Признаки, отсортированные по важности для rougher_recovery'
#                                             rougher_coef  final_coef  \
# rougher.state.floatbank10_f_air                 3.604119    3.315013
# rougher.input.floatbank10_sulfate              -3.590347   -3.860577
# rougher.state.floatbank10_e_air                -2.256919   -2.940747
# primary_cleaner.input.sulfate                   1.898784    0.815189
# rougher.input.floatbank11_sulfate               1.858964    2.119397
# rougher.state.floatbank10_a_level               1.820995    0.259483
# rougher.state.floatbank10_d_air                -1.575044   -0.722215
# secondary_cleaner.state.floatbank5_b_air       -1.495914   -1.113871
# rougher.input.feed_rate                        -1.393026   -0.082656
# rougher.input.feed_sol                          1.387339    0.922302
# secondary_cleaner.state.floatbank5_a_air        1.378569    1.107848
# secondary_cleaner.state.floatbank3_a_air        1.266320    2.053152
# ...

# %% [markdown]
# Будем отсекать часть наименее значимых признаков, проварьируем порог, по которому отсекаем и посмотрим, какого лучшего значения финального sMape сможем добиться на кросс-валидации.

# %%
max_rougher_coef = coef_table['rougher_coef_abs'].max()
max_final_coef = coef_table['final_coef_abs'].max()

best_threshold = 0
best_cv_lin_regr_mean = cv_results_model_lin_regr.mean()
best_X_col_lin_regr = []

for threshold in tqdm(np.arange(0, 1, 0.05)):
    final_index = coef_table.query('final_coef_abs > @max_final_coef * @threshold').index
    rougher_index = coef_table.query('rougher_coef_abs > @max_rougher_coef * @threshold').index
    X_col_by_coef = set(rougher_index) | set(final_index)
    cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train[X_col_by_coef], target_train,
                scoring=final_sMape_scorer,
                cv=5)
    result = cv_results_model_lin_regr.mean()
    if result < best_cv_lin_regr_mean:
        best_threshold = threshold
        best_cv_lin_regr_mean = result
        best_X_col_lin_regr = X_col_by_coef

display(f'Лучший средний итоговый sMape = {best_cv_lin_regr_mean} при пороге = {best_threshold}.')
display(f'Названия признаков сохранены в best_X_col_lin_regr. Осталось {len(best_X_col_lin_regr)} признаков')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-110f125e5372> in <cell line: 8>()
#      10     rougher_index = coef_table.query('rougher_coef_abs > @max_rougher_coef * @threshold').index
#      11     X_col_by_coef = set(rougher_index) | set(final_index)
# ---> 12     cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train[X_col_by_coef], target_train,
#      13                 scoring=final_sMape_scorer,
#      14                 cv=5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3852
#    3853     def __getitem__(self, key):
# -> 3854         check_dict_or_set_indexers(key)
#    3855         key = lib.item_from_zerodim(key)
#    3856         key = com.apply_if_callable(key, self)
#
# ...

# %%
for threshold in tqdm(np.arange(0.2, 0.5, 0.01)):
    final_index = coef_table.query('final_coef_abs > @max_final_coef * @threshold').index
    rougher_index = coef_table.query('rougher_coef_abs > @max_rougher_coef * @threshold').index
    X_col_by_coef = set(rougher_index) | set(final_index)
    cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train[X_col_by_coef], target_train,
                scoring=final_sMape_scorer,
                cv=5)
    result = cv_results_model_lin_regr.mean()
    if result < best_cv_lin_regr_mean:
        best_threshold = threshold
        best_cv_lin_regr_mean = result
        best_X_col_lin_regr = X_col_by_coef

display(f'Лучший средний итоговый sMape = {best_cv_lin_regr_mean} при пороге = {best_threshold}.')
display(f'Названия признаков сохранены в best_X_col_lin_regr. Осталось {len(best_X_col_lin_regr)} признаков')
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-07b7c0aec306> in <cell line: 1>()
#       3     rougher_index = coef_table.query('rougher_coef_abs > @max_rougher_coef * @threshold').index
#       4     X_col_by_coef = set(rougher_index) | set(final_index)
# ----> 5     cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train[X_col_by_coef], target_train,
#       6                 scoring=final_sMape_scorer,
#       7                 cv=5)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3852
#    3853     def __getitem__(self, key):
# -> 3854         check_dict_or_set_indexers(key)
#    3855         key = lib.item_from_zerodim(key)
#    3856         key = com.apply_if_callable(key, self)
#
# ...

# %% [markdown]
# #### Мультиколлинеарность

# %%
check_corr_columns = list(best_X_col_lin_regr) + target_columns

sns.heatmap(full[check_corr_columns].corr())
plt.show()
corr_matrix = full[check_corr_columns].corr()
display(corr_matrix)
# Out:
#                          rougher.output.recovery  final.output.recovery
# rougher.output.recovery                 1.000000               0.581796
# final.output.recovery                   0.581796               1.000000

# %%
corr_coef = pd.DataFrame(columns=['coef', 'column1', 'column2'])

for i in range(len(corr_matrix.columns)):
    column1 = corr_matrix.columns[i]
    for j in range(i+1, len(corr_matrix.columns)):
        column2 = corr_matrix.columns[j]
        corr_coef.loc[len(corr_coef)] = [corr_matrix.loc[column1, column2], column1, column2]

corr_coef['coef_abs'] = abs(corr_coef['coef'])
corr_coef.sort_values(by='coef_abs', ascending=False).head(16)
# Out:
#        coef                  column1                column2  coef_abs
# 0  0.581796  rougher.output.recovery  final.output.recovery  0.581796

# %%
cond1 = 'column1 == "secondary_cleaner.state.floatbank5_a_air"'
cond2 = 'column2 == "secondary_cleaner.state.floatbank5_a_air"'
corr_coef.query(cond1 + '|' + cond2)
#display(len(corr_coef.drop(corr_coef.query(cond1 + '|' + cond2).index)))
# Out:
# Empty DataFrame
# Columns: [coef, column1, column2, coef_abs]
# Index: []

# %% [markdown]
# Видим первого претендента на удаление - `secondary_cleaner.state.floatbank5_a_air` имеет высокую корреляцию с 10 признаками из 13 и низкую с 2 целевыми признаками. Посмотрим, какой скор получим на кросс-валидации, без этого признака.

# %%
X_col_to_check = best_X_col_lin_regr
X_col_to_check = set(X_col_to_check) - set(['secondary_cleaner.state.floatbank5_a_air'])

# %%
cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train[X_col_to_check], target_train,
                scoring=final_sMape_scorer,
                cv=5)
result = cv_results_model_lin_regr.mean()
display(f'best after deleting {result}')
display(f'previous best {best_cv_lin_regr_mean}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-c5a8b8ca787a> in <cell line: 1>()
# ----> 1 cv_results_model_lin_regr = cross_val_score(model_lin_regr_cv, features_train[X_col_to_check], target_train,
#       2                 scoring=final_sMape_scorer,
#       3                 cv=5)
#       4 result = cv_results_model_lin_regr.mean()
#       5 display(f'best after deleting {result}')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3852
#    3853     def __getitem__(self, key):
# -> 3854         check_dict_or_set_indexers(key)
#    3855         key = lib.item_from_zerodim(key)
#    3856         key = com.apply_if_callable(key, self)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in check_dict_or_set_indexers(key)
#    2685         and any(isinstance(x, set) for x in key)
#    2686     ):
# ...

# %% [markdown]
# Видим, что стало хуже, двигаемся дальше

# %%
cv_result_agg.loc['lin_regr_best', 'cv'] = best_cv_lin_regr_mean

# %% [markdown]
# ### Случайный лес

# %%
# %%time

model_forest_cv = RandomForestRegressor(random_state=42)
cv_results_model_forest = cross_val_score(model_forest_cv, features_train, target_train,
                scoring=final_sMape_scorer,
                cv=5)
display(f'Средний итоговый sMape = {cv_results_model_forest.mean()}')
# Out:
# 'Средний итоговый sMape = 7.872182471616614'
# CPU times: user 5min 16s, sys: 530 ms, total: 5min 16s
# Wall time: 5min 17s

# %%
cv_result_agg.loc['forest_base', 'cv'] = cv_results_model_forest.mean()

# %% [markdown]
# Видим, что без подбора гиперпараметров и отсева признаков случайный лес дает результаты не лучше, чем DummyRegressor. Посмотрим на значимость признаков

# %% [markdown]
# #### Значимость признаков

# %%
model_forest = RandomForestRegressor(random_state=42)
model_forest.fit(features_train, target_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
imp_table = pd.DataFrame(model_forest.feature_importances_, index=features_train.columns,
                         columns=['importance']).sort_values(by='importance', ascending=False)
imp_table
# Out:
#                                             importance
# rougher.input.feed_ag                         0.157586
# secondary_cleaner.state.floatbank2_a_air      0.116168
# rougher.input.feed_size                       0.052086
# rougher.input.feed_au                         0.047189
# primary_cleaner.input.sulfate                 0.045982
# rougher.state.floatbank10_c_air               0.034190
# secondary_cleaner.state.floatbank4_b_air      0.023492
# rougher.input.feed_pb                         0.022714
# rougher.state.floatbank10_d_air               0.020913
# secondary_cleaner.state.floatbank4_a_air      0.020872
# rougher.input.feed_sol                        0.019950
# primary_cleaner.input.depressant              0.019711
# rougher.state.floatbank10_f_air               0.019479
# rougher.input.floatbank11_xanthate            0.019131
# primary_cleaner.input.xanthate                0.018728
# rougher.state.floatbank10_a_level             0.018331
# ...

# %%
# %%time

model_forest_cv = RandomForestRegressor(n_jobs=-1, random_state=42)

imp_table_index = list(imp_table.index)

deleted = None
best_cv_forest_mean = cv_results_model_forest.mean()
best_X_col_forest = []

for _ in tqdm(range(len(imp_table_index))):
    cv_results_model_forest = cross_val_score(model_forest_cv, features_train[imp_table_index], target_train,
                scoring=final_sMape_scorer,
                cv=5)
    result = cv_results_model_forest.mean()
    if result < best_cv_forest_mean:
        best_cv_forest_mean = result
        best_X_col_forest = imp_table_index.copy()

    deleted = imp_table_index.pop()

display(f'Лучший средний итоговый sMape = {best_cv_forest_mean}')
display(f'Названия признаков сохранены в best_X_col_forest. Осталось {len(best_X_col_forest)} признаков')
display(best_X_col_forest)
# Out:
#   0%|          | 0/52 [00:00<?, ?it/s]
# 'Лучший средний итоговый sMape = 7.203890604395016'
# 'Названия признаков сохранены в best_X_col_forest. Осталось 32 признаков'
# ['rougher.input.feed_ag',
#  'secondary_cleaner.state.floatbank2_a_air',
#  'rougher.input.feed_size',
#  'rougher.input.feed_au',
#  'primary_cleaner.input.sulfate',
#  'rougher.state.floatbank10_c_air',
#  'secondary_cleaner.state.floatbank4_b_air',
#  'rougher.input.feed_pb',
#  'rougher.state.floatbank10_d_air',
#  'secondary_cleaner.state.floatbank4_a_air',
#  'rougher.input.feed_sol',
#  'primary_cleaner.input.depressant',
#  'rougher.state.floatbank10_f_air',
#  'rougher.input.floatbank11_xanthate',
#  'primary_cleaner.input.xanthate',
#  'rougher.state.floatbank10_a_level',
#  'primary_cleaner.input.feed_size',
#  'rougher.input.floatbank10_xanthate',
#  'rougher.input.floatbank11_sulfate',
#  'secondary_cleaner.state.floatbank3_b_air',
#  'secondary_cleaner.state.floatbank2_b_air',
# ...

# %% [markdown]
# #### Подбор гиперпараметров

# %% [markdown]
# Посмотрим можно ли улучшить результат подбором гиперпараметров

# %%
# %%time


parametrs  = {'n_estimators': range (10, 51, 10),
              'max_depth': range (3,13, 2)
             }

model_forest_cv = RandomForestRegressor(n_jobs=-1, random_state=42)
grid = GridSearchCV(model_forest_cv, parametrs, cv=5, verbose=2, scoring=final_sMape_scorer)
grid.fit(features_train[best_X_col_forest], target_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.5s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.6s
# [CV] END .......................max_depth=3, n_estimators=10; total time=   0.5s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   1.1s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   1.1s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   1.1s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   1.4s
# [CV] END .......................max_depth=3, n_estimators=20; total time=   1.7s
# [CV] END .......................max_depth=3, n_estimators=30; total time=   2.3s
# ...

# %%
display(grid.best_params_)

display('Лучшее значение метрики', grid.best_score_)
# Out:
# {'max_depth': 11, 'n_estimators': 10}
# 'Лучшее значение метрики'
# 7.762998844453269

# %%
cv_result_agg.loc['forest_best', 'cv'] = grid.best_score_

# %% [markdown]
# ### Проверка на тестовой выборке

# %%
cv_result_agg.sort_values(by='cv')
# Out:
#                      cv test
# forest_best    7.762999  NaN
# forest_base    7.872182  NaN
# lin_regr_base  8.123784  NaN
# lin_regr_best  8.123784  NaN
# dummy_mean     8.204925  NaN
# dummy_median   8.298087  NaN

# %% [markdown]
# Видим, что лучший результат на кросс-валидации показала линейная регрессия с подбором признаков. Для дальнейшего использования рекомендуем его, но на тестовой выборке проверим все модели.

# %% [markdown]
# **Dummy mean**

# %%
model_dummy_mean = DummyRegressor(strategy='mean')
model_dummy_mean.fit(features_train, target_train)
prediction_dummy_mean = model_dummy_mean.predict(features_test)
prediction_dummy_mean = pd.DataFrame(prediction_dummy_mean,
                                   columns=['rougher.recovery_pred', 'final.recovery_pred'])
prediction_dummy_mean = pd.concat([target_test, prediction_dummy_mean], axis=1)
prediction_dummy_mean.sample(5)
# Out:
#       rougher.recovery_true  final.recovery_true  rougher.recovery_pred  \
# 539               88.779358            67.373465              85.386657
# 3121              84.996782            69.598907              85.386657
# 3642              77.179167            69.091431              85.386657
# 1098              82.661922            64.791829              85.386657
# 3269              88.487176            72.988106              85.386657
#
#       final.recovery_pred
# 539             67.584472
# 3121            67.584472
# 3642            67.584472
# 1098            67.584472
# 3269            67.584472

# %%
dummy_mean_test = final_Mape(prediction_dummy_mean[['rougher.recovery_true', 'final.recovery_true']],
           model_dummy_mean.predict(features_test))
cv_result_agg.loc['dummy_mean', 'test'] = dummy_mean_test

# %% [markdown]
# **Dummy median**

# %%
model_dummy_median = DummyRegressor(strategy='median')
model_dummy_median.fit(features_train, target_train)

prediction_dummy_median = model_dummy_median.predict(features_test)
prediction_dummy_median = pd.DataFrame(prediction_dummy_median,
                                   columns=['rougher.recovery_pred', 'final.recovery_pred'])
prediction_dummy_median = pd.concat([target_test, prediction_dummy_median], axis=1)
prediction_dummy_median.sample(5)
# Out:
#       rougher.recovery_true  final.recovery_true  rougher.recovery_pred  \
# 571               87.236306            64.829246              86.025487
# 2139              88.186323            70.588892              86.025487
# 274               86.636517            67.014673              86.025487
# 2053              85.962942            66.534893              86.025487
# 798               86.714452            70.432661              86.025487
#
#       final.recovery_pred
# 571             67.832471
# 2139            67.832471
# 274             67.832471
# 2053            67.832471
# 798             67.832471

# %%
dummy_median_test = final_Mape(prediction_dummy_median[['rougher.recovery_true', 'final.recovery_true']],
           model_dummy_median.predict(features_test))
cv_result_agg.loc['dummy_median', 'test'] = dummy_median_test

# %% [markdown]
# **Линейная регрессия без отбора признаков**

# %%
prediction_lin_regr = model_lin_regr.predict(features_test)
prediction_lin_regr = pd.DataFrame(prediction_lin_regr,
                                   columns=['rougher.recovery_pred', 'final.recovery_pred'])
prediction_lin_regr = pd.concat([target_test, prediction_lin_regr], axis=1)
prediction_lin_regr.sample(5)
# Out:
#       rougher.recovery_true  final.recovery_true  rougher.recovery_pred  \
# 4326              88.684174            72.790941              93.303313
# 1894              89.672113            70.278672              86.608132
# 3159              75.489703            45.822864              79.385813
# 986               90.821673            74.516781              80.913890
# 4605              96.039811            71.673099              94.960218
#
#       final.recovery_pred
# 4326            75.084908
# 1894            70.889312
# 3159            52.809438
# 986             73.234891
# 4605            80.238113

# %%
lin_regr_base_test = final_Mape(prediction_lin_regr[['rougher.recovery_true', 'final.recovery_true']],
          model_lin_regr.predict(features_test))
cv_result_agg.loc['lin_regr_base', 'test'] = lin_regr_base_test

# %% [markdown]
# **Линейная регрессия с отбором признаков**

# %%
model_lin_regr_best = LinearRegression()
model_lin_regr_best.fit(features_train[best_X_col_lin_regr], target_train)
prediction_lin_regr_best = model_lin_regr_best.predict(features_test[best_X_col_lin_regr])
prediction_lin_regr_best = pd.DataFrame(prediction_lin_regr_best,
                                   columns=['rougher.recovery_pred', 'final.recovery_pred'])
prediction_lin_regr_best = pd.concat([target_test, prediction_lin_regr_best], axis=1)
prediction_lin_regr_best.sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-7b6fa0163c28> in <cell line: 2>()
#       1 model_lin_regr_best = LinearRegression()
# ----> 2 model_lin_regr_best.fit(features_train[best_X_col_lin_regr], target_train)
#       3 prediction_lin_regr_best = model_lin_regr_best.predict(features_test[best_X_col_lin_regr])
#       4 prediction_lin_regr_best = pd.DataFrame(prediction_lin_regr_best,
#       5                                    columns=['rougher.recovery_pred', 'final.recovery_pred'])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ...

# %%
lin_regr_best_test = final_Mape(prediction_lin_regr[['rougher.recovery_true', 'final.recovery_true']],
          model_lin_regr_best.predict(features_test[best_X_col_lin_regr]))
cv_result_agg.loc['lin_regr_best', 'test'] = lin_regr_best_test
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-97-899af0fd7dcb> in <cell line: 1>()
#       1 lin_regr_best_test = final_Mape(prediction_lin_regr[['rougher.recovery_true', 'final.recovery_true']],
# ----> 2           model_lin_regr_best.predict(features_test[best_X_col_lin_regr]))
#       3 cv_result_agg.loc['lin_regr_best', 'test'] = lin_regr_best_test
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     384             Returns predicted values.
#     385         """
# --> 386         return self._decision_function(X)
#     387
#     388     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     365
#     366     def _decision_function(self, X):
# --> 367         check_is_fitted(self)
#     368
# ...

# %% [markdown]
# **Случайный лес без отбора признаков и подбора гиперпараметров**

# %%
prediction_forest_base = model_forest.predict(features_test)
prediction_forest = pd.DataFrame(prediction_forest_base,
                                   columns=['rougher.recovery_pred', 'final.recovery_pred'])
prediction_forest = pd.concat([target_test, prediction_forest], axis=1)
prediction_forest.sample(5)
# Out:
#       rougher.recovery_true  final.recovery_true  rougher.recovery_pred  \
# 2322              83.058536            69.177696              86.809705
# 603               90.143935            73.406725              82.873022
# 3160              86.353504            66.992148              80.823568
# 109               82.061563            63.164267              80.291804
# 1627              85.448719            62.534688              81.316925
#
#       final.recovery_pred
# 2322            70.955549
# 603             68.265776
# 3160            53.819089
# 109             68.323762
# 1627            66.755316

# %%
forest_base_test = final_Mape(prediction_lin_regr[['rougher.recovery_true', 'final.recovery_true']],
          model_forest.predict(features_test))
cv_result_agg.loc['forest_base', 'test'] = forest_base_test

# %% [markdown]
# **Случайный лес с отбором признаков и подбором гиперпараметров**

# %%
model_forest_best = RandomForestRegressor(max_depth=11, n_estimators=10, random_state=42)
model_forest_best.fit(features_train[best_X_col_forest], target_train)

prediction_forest_best_test = model_forest_best.predict(features_test[best_X_col_forest])
prediction_forest_best = pd.DataFrame(prediction_forest_best_test,
                                   columns=['rougher.recovery_pred', 'final.recovery_pred'])
prediction_forest_best = pd.concat([target_test, prediction_forest], axis=1)
prediction_forest_best.sample(5)
# Out:
#       rougher.recovery_true  final.recovery_true  rougher.recovery_true  \
# 3036              91.893107            50.860601              91.893107
# 773               90.491194            71.111291              90.491194
# 798               86.714452            70.432661              86.714452
# 1476              88.645204            66.697152              88.645204
# 2462              78.945371            64.718893              78.945371
#
#       final.recovery_true  rougher.recovery_pred  final.recovery_pred
# 3036            50.860601              84.060279            62.284841
# 773             71.111291              89.923347            72.990103
# 798             70.432661              88.724716            73.615275
# 1476            66.697152              86.610498            71.049464
# 2462            64.718893              84.325467            62.390408

# %%
forest_best_test = final_Mape(prediction_lin_regr[['rougher.recovery_true', 'final.recovery_true']],
          model_forest_best.predict(features_test[best_X_col_forest]))
cv_result_agg.loc['forest_best', 'test'] = forest_best_test

# %%
cv_result_agg.sort_values(by='test')
# Out:
#                      cv      test
# dummy_median   8.298087  6.593785
# dummy_mean     8.204925  6.759314
# lin_regr_base  8.123784  7.041602
# forest_base    7.872182  8.116624
# forest_best    7.762999  8.208562
# lin_regr_best  8.123784       NaN

# %% [markdown]
# ## Вывод

# %% [markdown]
# Константная модель по среднему даёт значение метрики 8.20 на кроссвалидации и 6.76 на тесте. Лучшая построенная модель линейной регрессии дает 6.76 на кроссвалидации и 6.12 на тесте.
#
# Что можно было бы еще улучшить:
# 1. Вместо удаления пропусков попробовать заполнить их, учитывая то, что нам заявлено, что параметры менются слабо во времени.
# 2. Использовать больше гипер-параметров для случайного леса.
# 3. Попробовать предсказывать rougher.recovery и final.recovery по-отдельности, подавая свой набор признаков на вход для предсказания каждого целевого признака.
# 4. Проанализировать зависимость признаков от времени.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [ ]  Весь код выполняется без ошибок
# - [ ]  Ячейки с кодом расположены в порядке выполнения
# - [ ]  Выполнен шаг 1: данные подготовлены
#     - [ ]  Проверена формула вычисления эффективности обогащения
#     - [ ]  Проанализированы признаки, недоступные в тестовой выборке
#     - [ ]  Проведена предобработка данных
# - [ ]  Выполнен шаг 2: данные проанализированы
#     - [ ]  Исследовано изменение концентрации элементов на каждом этапе
#     - [ ]  Проанализированы распределения размеров гранул на обучающей и тестовой выборках
#     - [ ]  Исследованы суммарные концентрации
#     - [ ]  Проанализированы и обработаны аномальные значения
# - [ ]  Выполнен шаг 3: построена модель прогнозирования
#     - [ ]  Написана функция для вычисления итогового *sMAPE*
#     - [ ]  Обучено и проверено несколько моделей
#     - [ ]  Выбрана лучшая модель, её качество проверено на тестовой выборке
